# %%
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI, RateLimitError
import os
import time

load_dotenv()

deployment_name='gpt4Test'
max_tokens=4096

client = AzureOpenAI(
    api_key=os.getenv("AZURE_API_KEY"),  
    api_version=os.getenv("AZURE_API_VERSION"),
    azure_endpoint=os.getenv("AZURE_ENDPOINT")
)

def generate_chat_gpt_query(prompt):
    response = client.chat.completions.create(
        model=deployment_name,
        messages=[
            {"role": "user", "content": prompt}
        ],
        max_tokens=max_tokens,
        temperature=0,
        n=1,
        stop=None
    )

    if response.choices:
        return response.choices[0].message.content.strip()
    else:
        return "No suggestion generated."
    
df = pd.read_csv("dataset_with_sentiment.csv")

df_negative = df[df['label'] == 'negative']

specific_days = ['2023-01-02', '2022-12-16']

df_specific_days = df_negative[df_negative['day'].isin(specific_days)].drop(columns=["Unnamed: 0"])

context = df_specific_days.to_json(orient="records")

query = (
    "Given context contains negative feedbacks from my team received during sprint retrospectives from days: " + ", ".join(specific_days) + "\n"
    "1. What common themes or patterns do you detect in the negative feedback provided over the different days?\n"
    "2. Highlight feedbacks from the same topic which appear most frequently.\n"
)

prompt = "Context:\n" + context + "\n\n Prompt:\n" + query
print(prompt)
ai_response = generate_chat_gpt_query(prompt)
print(ai_response)
# Out:
# Context:
# [{"day":"2022-12-16","text":"smaller team because of the holiday period","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"high severity bug found in production","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"slightly overwhelmed by new environment","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"mau report broke quota","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"communication issues on sprint review","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"operation crush","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"disappointed quality of  content","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"sad bugs are not getting better treatment","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"backlog  ownership","human_label":"neutral","label":"negative"},{"day":"2022-12-16","text":"communication issues on sprint review","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"feeling sad about the fact that we don't know hoe integration with jira\/ conf server works","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"too much manual testing","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"too many bugs in jira \/conf server","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"guest access to features is confusing","human_label":"negative","label":"negative"},{"day":"2022-12-16","text":"20+ bugs","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"tech debt meetings","human_label":"neutral","label":"negative"},{"day":"2023-01-02","text":"turned off cameras","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"huge mess on daily board","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"cannot find my task","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"cannot find a task that we are talking about","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"placement of the task \/ location is  meanigless","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"lags of audio","human_label":"negative","label":"negative"},{"day":"2023-01-02","text":"blurry video","human_label":"negative","label":"negative"}]
#
#  Prompt:
# Given context contains negative feedbacks from my team received during sprint retrospectives from days: 2023-01-02, 2022-12-16
# 1. What common themes or patterns do you detect in the negative feedback provided over the different days?
# 2. Highlight feedbacks from the same topic which appear most frequently?
#
# 1. **Common Themes or Patterns Detected:**
#
#    - **Technical Issues and Bugs:** A significant portion of the feedback revolves around technical problems, such as high severity bugs in production, too many bugs in Jira/Confluence server, and the presence of 20+ bugs. This indicates a recurring issue with software quality and stability.
#
#    - **Process and Workflow Challenges:** Several comments highlight difficulties with the team's processes and workflows. This includes communication issues during sprint reviews, problems with the daily board (e.g., a huge mess on the daily board, inability to find tasks), and manual testing being too burdensome. There's also mention of tech debt meetings, suggesting ongoing concerns with managing technical debt.
#
#    - **Tool and Infrastructure Problems:** Feedback points to issues with the tools and infrastructure used by the team, such as problems integrating with Jira/Confluence server, guest access to features being confusing, and technical difficulties during remote meetings (e.g., turned off cameras, lags of audio, blurry video).
#
#    - **Team Dynamics and Morale:** There are indications of negative impacts on team morale and dynamics, such as feeling overwhelmed, disappointment with the quality of content, and sadness about bugs not receiving proper attention. The mention of a smaller team due to the holiday period could also suggest challenges with resource allocation and workload distribution.
#
# 2. **Feedbacks from the Same Topic Appearing Most Frequently:**
#
#    - **Technical Issues and Bugs:**
#      - "high severity bug found in production"
#      - "too many bugs in jira /conf server"
#      - "20+ bugs"
#
#    - **Process and Workflow Challenges:**
#      - "communication issues on sprint review" (mentioned twice)
#      - "huge mess on daily board"
#      - "cannot find my task"
#      - "cannot find a task that we are talking about"
#
#    - **Tool and Infrastructure Problems:**
#      - "feeling sad about the fact that we don't know how integration with jira/conf server works"
#      - "guest access to features is confusing"
#
#    - **Remote Meeting Difficulties:**
#      - "turned off cameras"
#      - "lags of audio"
#      - "blurry video"
#
# These patterns and repeated feedbacks suggest focal areas for improvement, including enhancing software quality, refining processes and workflows, addressing tool and infrastructure issues, and improving remote communication and team morale.
